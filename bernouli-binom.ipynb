# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## success of india in winning a match is 0.55046

# %%
from scipy.stats import bernoulli
success=0.55046
mean,variance=bernoulli.stats(success)
print('mean - %s and varaince -%s'%(mean,variance))
# Out:
# mean - 0.55046 and varaince -0.2474537884

# %%
x=np.arange(0,5,1)
plt.bar(x,bernoulli.pmf(x,success))
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Bernouli shows success of winning of a single match

# %%
from scipy.stats import binom

# %% [markdown]
# ## creating binomial distribution for next 30 matches of india

# %%
n=30
x=np.arange(0,n,1)
plt.title('binomial distribution for india\'s next 30 matches')
plt.xlabel('won matches')
plt.ylabel('probability of  event')
plt.plot(x,binom.pmf(x,n,success))

# %% [markdown]
# ## graph shows that probability of winning approx 16-17 matches is max.
